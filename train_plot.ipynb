# %%
import matplotlib.pyplot as plt
import os
import re
from train import load_log

# %%
log_dir = ".\\log\\linear_L1_C_1e_2_2022_12_23_22_56_46_672272" 
epochs, losses, accuracies = load_log(log_dir)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 2
#       1 log_dir = ".\\log\\linear_L1_C_1e_2_2022_12_23_22_56_46_672272"
# ----> 2 load_log(log_dir)
#
# NameError: name 'load_log' is not defined

# %%
plt.title("Accuracy & Loss")
plt.plot(epochs, losses, color = '#1f77b4')
plt.xlabel("epochs")
plt.ylabel("loss")
ax2=plt.twinx()
plt.ylabel("accuracy %")
ax2.plot(epochs, accuracies, color = '#ff7f0e')
